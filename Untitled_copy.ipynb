# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import seaborn as sns
import collections
import pandas as pd

# %%
DATASET_BASE_PATH = 'dataset'

# %%
bird_names = ['comcuc', 'cowpig1', 'eucdov', 'eueowl1', 'grswoo', 'tawowl1']

# %%
def load_feature_names():
    with open(os.path.join(DATASET_BASE_PATH, 'feature_names.txt')) as f:
        return f.read().split('\n')

# %%
def load_annotations_for_file(bird: str, file_nr):
    data = np.load(os.path.join(DATASET_BASE_PATH, bird, f'{file_nr}.npy'))
    labels = np.load(os.path.join(DATASET_BASE_PATH, bird, f'{file_nr}.labels.npy'))
    return data, labels

# %%
def get_file_nrs_of_bird(bird: str):
    return [f.split('.')[0] for f in os.listdir(os.path.join(DATASET_BASE_PATH, bird))[::2]]

# %%
def load_annotations_for_bird_array(bird: str):
    file_nrs = get_file_nrs_of_bird(bird)
    data_arrays = np.zeros(shape=(len(file_nrs),100, 548))
    label_arrays = np.zeros(shape=(len(file_nrs),100,1))
    for i,file_nr in enumerate(file_nrs):
        data, labels = load_annotations_for_file(bird, file_nr)
        data_arrays[i] = data
        label_arrays[i] = labels[:,0][..., np.newaxis]
    data_arrays = data_arrays.reshape(-1, 548)
    label_arrays = label_arrays.reshape(-1,)
    return data_arrays, label_arrays

# %%
X = np.zeros(shape=(6,20000,548))
y = np.zeros(shape=(6,20000))
for i, bird_name in enumerate(bird_names):
    data_arr, label_arr = load_annotations_for_bird_array(bird_name)
    X[i] = data_arr
    y[i] = label_arr
X = X.reshape(-1, 548)
y = y.reshape(-1,)
print(X.shape, y.shape)
# Out:
# (120000, 548) (120000,)

# %%
from sklearn.preprocessing import StandardScaler
X_std = StandardScaler().fit_transform(X)

# %%
df = pd.DataFrame(data= X_std)
df['label'] = y

# %%
df
# Out:
#                0         1         2         3         4         5         6  \
# 0       0.324853  2.234985 -0.461250 -0.459697 -0.458253 -0.460968 -0.465535
# 1       0.989178  0.132790 -0.469780 -0.450666 -0.448523 -0.450307 -0.451012
# 2       1.194685  0.010198 -0.453683 -0.453699 -0.450746 -0.452051 -0.449489
# 3       1.469728 -0.275156 -0.452810 -0.452095  1.038133  1.033007  1.038578
# 4       1.447376  0.114848 -0.471611  1.085548  1.090256  1.080141  1.083316
# ...          ...       ...       ...       ...       ...       ...       ...
# 119995 -0.307808 -0.400559 -0.594240 -0.601831 -0.586475 -0.599853 -0.588341
# 119996 -0.441294 -0.619189 -0.598058 -0.590810 -0.589035 -0.589904 -0.587234
# 119997 -0.323950 -0.562923 -0.598347 -0.598618 -0.596927 -0.587339 -0.597913
# 119998 -0.386658 -0.573564 -0.552378 -0.552066 -0.546696 -0.584835 -0.573869
# 119999 -0.540011 -0.335069 -0.535083 -0.587384 -0.583594 -0.576394 -0.575889
#
#                7         8         9  ...       539       540       541  \
# 0      -0.449217 -0.451182 -0.547805  ... -0.172302  0.080310  2.470300
# 1      -0.450295 -0.451634 -0.450558  ...  0.151305  0.105084  1.061932
# 2      -0.449706 -0.450521 -0.449023  ... -0.407717 -0.003469 -1.158163
# 3       1.070068  1.076200  1.079808  ... -0.415646 -0.001220  0.043979
# 4       1.097960  1.085294  1.094416  ... -0.574759  0.002824 -0.077341
# ...          ...       ...       ...  ...       ...       ...       ...
# 119995 -0.591748 -0.601566 -0.600409  ... -0.836325 -0.697713  0.937012
# 119996 -0.585571 -0.594526 -0.593013  ... -0.535147 -0.703345  0.337411
# 119997 -0.597698 -0.598575 -0.582482  ... -0.805287 -0.632309 -0.203184
# 119998 -0.583535 -0.584801 -0.584532  ... -0.471637 -0.623406 -0.158139
# 119999 -0.588442 -0.588116 -0.587149  ... -0.455527 -0.664853 -0.919209
#
#              542       543       544       545       546       547  label
# 0       0.530690  0.550376  1.346904  0.440528  1.204424 -0.304300    0.0
# 1       1.853208 -1.044705 -0.787284 -0.567376 -0.374989  0.278298    0.0
# 2       1.589867 -0.405181 -1.129201  0.208342 -0.603692  0.199675    0.0
# 3       0.587352  1.090300 -0.714864  0.054454 -0.868647 -0.086277    0.0
# 4       0.057453  1.533986  0.253063 -0.370477 -0.390308 -0.083962    0.0
# ...          ...       ...       ...       ...       ...       ...    ...
# 119995 -1.265575  0.901798 -0.437241 -0.755890 -0.317793 -0.489154    0.0
# 119996 -0.006167 -0.675841  0.552243 -0.135932 -1.124722 -0.480388    0.0
# 119997  1.107725  1.066933  0.066132  0.156849 -1.321141 -0.735044    0.0
# 119998 -0.297675 -0.309379 -0.096192 -1.239868 -0.849260 -0.353855    0.0
# 119999 -0.402968  2.993323 -0.569557 -0.181408 -0.623800 -0.538711    0.0
#
# [120000 rows x 549 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(random_state=0)
forest.fit(X_std, y)
# Out:
# RandomForestClassifier(random_state=0)

# %%
importances = forest.feature_importances_

# %%
data_X = df.iloc[:,:-1]  #independent columns
data_y = df.iloc[:,-1]    #target column i.e price range
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(data_X,data_y)
# Out:
# ExtraTreesClassifier()

# %%
# print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=data_X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %%
print(feat_importances.nlargest(10).index)
# Out:
# Index([537, 271, 22, 522, 23, 289, 288, 21, 348, 349], dtype='object')

# %%
topk_features= list(feat_importances.nlargest(10).index)
# topk_features.append(len(df.columns)-1)
corrmat = df.iloc[:,topk_features].corr()
# print(corrmat)
top_corr_features = corrmat.index
print(top_corr_features)
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),cmap="RdYlGn")
# Out:
# Index([537, 271, 22, 522, 23, 289, 288, 21, 348, 349], dtype='object')

# %%
from sklearn.decomposition import PCA, KernelPCA
pca = PCA(n_components=2)
X_down = pca.fit_transform(df.iloc[:,topk_features])

# %%
pca.explained_variance_ratio_
# Out:
# array([0.49265072, 0.18978474])

# %%
idx = np.arange(0,120000, 10)
plt.scatter(X_down[idx,0], X_down[idx,1], c=y[idx])

# %%
  # plotting correlation heatmap for all features
data_corr = df.iloc[:,:-1].corr()
fig, ax = plt.subplots(figsize=(12,10))
dataplot = sns.heatmap(data_corr, ax=ax, xticklabels=100, yticklabels=100, cmap="RdYlGn")
  
# displaying heatmap
plt.show()

# %%
data_corr_np = data_corr.to_numpy()

# %%
data_corr_np.shape
# Out:
# (548, 548)

# %%
print(data_corr.shape)
# Out:
# (548, 548)

# %%
threshold = 0.8
abs_corr_matrix = data_corr.abs()
upper_tri = abs_corr_matrix.where(np.triu(np.ones(abs_corr_matrix.shape),k=1).astype(bool))
to_drop = [column for column in upper_tri.columns if any(upper_tri[column] >= threshold)]
print(len(to_drop))
# Out:
# 388

# %%
df_reduced = df.drop(df.columns[to_drop], axis=1)
df_reduced
# Out:
#                0         1         2        16        76        77        78  \
# 0       0.324853  2.234985 -0.461250  0.235287 -0.901281  0.363061  0.234093
# 1       0.989178  0.132790 -0.469780  0.414635 -0.641577 -0.117441  0.414609
# 2       1.194685  0.010198 -0.453683  0.355121  0.256044  0.159733 -0.929693
# 3       1.469728 -0.275156 -0.452810  0.210839  0.096418 -0.491433 -0.046122
# 4       1.447376  0.114848 -0.471611  0.357751  0.251199  0.352752 -0.675133
# ...          ...       ...       ...       ...       ...       ...       ...
# 119995 -0.307808 -0.400559 -0.594240  0.255726  0.208172  0.859027 -0.105199
# 119996 -0.441294 -0.619189 -0.598058  0.193310 -0.022139  0.042983  0.383651
# 119997 -0.323950 -0.562923 -0.598347  0.272899 -0.483865 -0.580620  0.436100
# 119998 -0.386658 -0.573564 -0.552378  0.349520 -0.108789 -1.301530  0.157032
# 119999 -0.540011 -0.335069 -0.535083  0.197309  3.133877  1.747610 -0.038833
#
#               79        80        81  ...       532       533       534  \
# 0       0.908987  0.840539  1.300153  ...  0.553743 -0.112544  3.660072
# 1      -0.182356 -0.572926 -0.407352  ...  0.096336 -0.332673  1.178250
# 2      -0.186252 -0.075692 -0.357577  ...  0.022049 -0.452060 -0.834817
# 3      -0.658404 -0.604739  0.362549  ...  0.297451 -0.537986  0.412554
# 4       1.615183 -0.051155 -0.777538  ...  0.376575 -0.605842  0.132424
# ...          ...       ...       ...  ...       ...       ...       ...
# 119995  0.777704 -0.730944 -0.422629  ...  0.434905 -0.688802  0.906499
# 119996 -1.124548 -0.645856 -0.310830  ...  0.735350 -0.492914  0.625478
# 119997  0.633512  0.309726 -0.736440  ...  0.620556 -0.557616 -0.039660
# 119998  0.305346 -0.257083 -0.299638  ...  0.644440 -0.458048  0.581867
# 119999  0.245533  0.104778  0.090026  ...  0.746568 -0.500894 -0.517461
#
#              535       536       538       539       540       542  label
# 0      -0.879086  0.137068  0.139324 -0.172302  0.080310  0.530690    0.0
# 1       1.039736 -0.860921 -0.824272  0.151305  0.105084  1.853208    0.0
# 2       0.926383  0.351227 -0.138128 -0.407717 -0.003469  1.589867    0.0
# 3       1.038409  0.297438 -0.453944 -0.415646 -0.001220  0.587352    0.0
# 4      -0.150753 -0.225968 -0.936384 -0.574759  0.002824  0.057453    0.0
# ...          ...       ...       ...       ...       ...       ...    ...
# 119995 -0.602067  0.011942 -0.482227 -0.836325 -0.697713 -1.265575    0.0
# 119996  0.410967 -0.234843 -0.205443 -0.535147 -0.703345 -0.006167    0.0
# 119997 -0.856680  0.438788 -0.136509 -0.805287 -0.632309  1.107725    0.0
# 119998 -0.035012  0.230688 -0.747289 -0.471637 -0.623406 -0.297675    0.0
# 119999 -0.406521  0.585169 -0.094116 -0.455527 -0.664853 -0.402968    0.0
#
# [120000 rows x 161 columns]

# %%
# df.corr()
  
# plotting correlation heatmap
data_corr_new = df_reduced.iloc[:,:-1].corr()
fig, ax = plt.subplots(figsize=(12,10))
dataplot = sns.heatmap(data_corr_new, ax=ax, xticklabels=10, yticklabels=10, cmap="RdYlGn")
  
# displaying heatmap
plt.show()

# %%
pca = PCA(n_components= 35)
X_down = pca.fit_transform(df_reduced.iloc[:,:-1])
print(X_down.shape)
# Out:
# (120000, 35)

# %%
from sklearn.manifold import TSNE
X_embedded = TSNE(n_components=2, learning_rate='auto',init='random', perplexity=3).fit_transform(X_down)
print(X_embedded.shape)
# Out:
# (120000, 2)

# %%
idx = np.arange(0,120000, 20)
plt.scatter(X_embedded[idx,0], X_embedded[idx,1], c=y[idx])

# %%
pca = PCA(n_components= 40)
X_down = pca.fit_transform(df.iloc[:,:-1])
print(X_down.shape)
# Out:
# (120000, 40)

# %%
from sklearn.manifold import TSNE
X_embedded_new = TSNE(n_components=2, learning_rate='auto',init='random', perplexity=3).fit_transform(X_down)
print(X_embedded_new.shape)
# Out:
# (120000, 2)

# %%
idx = np.arange(0,120000, 40)
plt.scatter(X_embedded_new[idx,0], X_embedded_new[idx,1], c=y[idx])
